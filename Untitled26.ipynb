# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshyadeepyadav/5pro/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U kaleido

# %%
# !git clone https://github.com/Lakshyadeepyadav/5pro.git
# %cd 5pro
# Out:
# Cloning into '5pro'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/3pro/5pro

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_absolute_error,r2_score

# %%
df=pd.read_csv("/content/Housing.csv")

# %%
x=df[["area"]]
y=df["price"]

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
x
# Out:
#      area
# 0    7420
# 1    8960
# 2    9960
# 3    7500
# 4    7420
# ..    ...
# 540  3000
# 541  2400
# 542  3620
# 543  2910
# 544  3850
#
# [545 rows x 1 columns]

# %%
y_pred=model.predict(X_test)

# %%
print("mae",mean_absolute_error(Y_test,y_pred))
# Out:
# mae 1474748.1337969352

# %%
print("mse",mean_absolute_error(Y_test,y_pred))
# Out:
# mse 1474748.1337969352

# %%
print("r2",r2_score(Y_test,y_pred))
# Out:
# r2 0.27287851871974644

# %%
plt.scatter(X_test,Y_test,color="blue",label=("real values"))
plt.plot(X_test,y_pred,color="red",label="linearregression")
